# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# ESTE ES EL EVENTO ALEATORIO
import random
   
def lanzar_dado():
    r1=random.randint(1,6)
    r2=random.randint(1,6)
    result=r1+r2
    return result

lanzar_dado()
# Out:
# 8

# %%
def simular_lanzamientos(num_simulaciones):
    even_number=0
    num_greater_than_7=0
    for _ in range (num_simulaciones):
        resultado = lanzar_dado()
        if resultado %2==0:
            even_number += 1
        if resultado > 7:
           num_greater_than_7 += 1
    print (f"Result even numbers:{even_number}\nResult numbers greater than 7:{num_greater_than_7}\nProbability of even numbers:{even_number/num_simulaciones}\nProbability numbers greater than 7:{num_greater_than_7/num_simulaciones}")

simular_lanzamientos(1000)
# Out:
# Result even numbers:512
# Result numbers greater than 7:409
# Probability of even numbers:0.512
# Probability numbers greater than 7:0.409

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(61):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

print(ball_box)
            
# TODO
# Out:
# {0: 'White', 1: 'White', 2: 'White', 3: 'White', 4: 'White', 5: 'White', 6: 'White', 7: 'White', 8: 'White', 9: 'White', 10: 'Red', 11: 'Red', 12: 'Red', 13: 'Red', 14: 'Red', 15: 'Red', 16: 'Red', 17: 'Red', 18: 'Red', 19: 'Red', 20: 'Red', 21: 'Red', 22: 'Red', 23: 'Red', 24: 'Red', 25: 'Red', 26: 'Red', 27: 'Red', 28: 'Red', 29: 'Red', 30: 'Green', 31: 'Green', 32: 'Green', 33: 'Green', 34: 'Green', 35: 'Green', 36: 'Green', 37: 'Green', 38: 'Green', 39: 'Green', 40: 'Green', 41: 'Green', 42: 'Green', 43: 'Green', 44: 'Green', 45: 'Green', 46: 'Green', 47: 'Green', 48: 'Green', 49: 'Green', 50: 'Green', 51: 'Green', 52: 'Green', 53: 'Green', 54: 'Green', 55: 'Green', 56: 'Green', 57: 'Green', 58: 'Green', 59: 'Green', 60: 'Green'}

# %%
import numpy as np
def experiment(num_simulations):
    count_1=0
    count_2=0
    for i in range(num_simulations):
        colors=[]
        for i in range(5):
            colors.append(ball_box[np.random.randint(1,60)])
        colors=np.array(colors)
        w_b=sum(colors=='White')
        r_b=sum(colors=='Red')
        g_b=sum(colors=='Green')
        if (w_b==3) and (r_b==2):
            count_1 +=1
        if (w_b==5) or (r_b==5)or(g_b==5):
            count_2 +=1   
    
    
    return print(f"Probabilite three white balls and two red balls:{np.round((count_1/num_simulations)*100,2)}%\nProbabilite five balls with the same color:{np.round((count_2/num_simulations)*100,2)}%")

experiment(1000)
# Out:
# Probabilite three white balls and two red balls:0.4%
# Probabilite five balls with the same color:4.3%

# %%
# def ball_out():
#     r1=random.randint(1,60)
#     r2=random.randint(1,60)
#     r3=random.randint(1,60)
#     r4=random.randint(1,60)
#     r5=random.randint(1,60)
#      #result=list([r1,r2,r3,r4,r5])
#     return r1,r2,r3,r4,r5

# ball_out()

# %%
# def num_tests(num_simulaciones):
#      balls={}
#      result = ball_out()
#      for i in result:
#         if i < 10:
#             balls[i]='white'
#         if (i > 9) and (i < 30):
#             balls[i]='Red'
#         else:
#             balls[i]='Green'
#         print(balls)
#         return balls
     
# num_tests(1000)

# %%
# def num_tests(num_simulaciones):
#      white=0
#      red=0
#      green=0
#      result = ball_out()
#      for i in result:
#         if i < 10:
#             white += 1
#         if (i > 9) and (i < 30):
#             red += 1
#         else:
#             green += 1
#         return (f"White: {white}\nRed: {red}\nGreen: {green}")

# num_tests(1)
